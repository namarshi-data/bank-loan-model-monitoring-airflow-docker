# %% [markdown]
# # 01 — Data Understanding and Extraction
#
# Load sample loan application data and review schema, date ranges, and target distribution.

# %%
import pandas as pd
df = pd.read_csv("../data/sample/loan_applications_sample.csv", parse_dates=["application_time"])
df.head()

# %%
df["loan_status"].value_counts(normalize=True).rename("share")
