# %% [markdown]
# # 06 — Drift Monitoring Reports
#
# Compare reference and current windows using numeric and categorical drift checks.

# %%
import sys, json
sys.path.append("../src")
from ml_monitoring.pipelines.batch_monitoring import run_pipeline
report = run_pipeline("../config/pipeline_config.yaml", source="sample", send_slack=False)
report["drift"]["summary"]
