# %% [markdown]
# # 05 — Best Model and Deployment Report
#
# Generate model documentation that a risk analytics or model governance reviewer can inspect.

# %%
import json, glob
print("Deployment reports are written to ../reports/model after running the pipeline.")
