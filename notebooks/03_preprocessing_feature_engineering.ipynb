# %% [markdown]
# # 03 — Preprocessing and Feature Engineering
#
# Demonstrate reusable feature engineering from the Python package.

# %%
import sys, pandas as pd
sys.path.append("../src")
from ml_monitoring.config import load_config
from ml_monitoring.features.preprocessing import engineer_features
config = load_config("../config/pipeline_config.yaml")
df = pd.read_csv("../data/sample/loan_applications_sample.csv")
engineered = engineer_features(df, config)
engineered[["debt_to_income_ratio", "credit_utilization_ratio", "application_month"]].head()
