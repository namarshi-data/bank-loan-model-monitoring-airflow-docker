# %% [markdown]
# # 00 — Architecture and Business Context
#
# This notebook explains the monitored loan eligibility use case, architecture, and responsible-use framing.

# %% [markdown]
# ## Business problem
#
# A trained model can degrade when borrower mix, product policy, macro conditions, or upstream data capture changes. This project monitors data quality, data drift, and model behaviour before recommending review or retraining.

# %%
from pathlib import Path
PROJECT_ROOT = Path.cwd().parents[0] if Path.cwd().name == "notebooks" else Path.cwd()
print(PROJECT_ROOT)
