# %% [markdown]
# # 02 — EDA and Data Quality
#
# Review missing values, duplicates, numeric ranges, and sanity checks.

# %%
import pandas as pd
df = pd.read_csv("../data/sample/loan_applications_sample.csv")
df.isna().mean().sort_values(ascending=False).head(10)

# %%
df.describe(include="all").T.head(20)
