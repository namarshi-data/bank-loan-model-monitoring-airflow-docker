# %% [markdown]
# # 07 — Airflow and Docker Orchestration
#
# This notebook documents the DAG flow. Run the full orchestration through Docker Compose and Airflow UI.

# %% [markdown]
# ```bash
# docker compose up -d --build
# docker compose exec airflow-scheduler python /opt/airflow/project/scripts/load_sample_to_postgres.py
# ```
