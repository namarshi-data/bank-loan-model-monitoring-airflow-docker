# %% [markdown]
# # 04 — Model Training and Evaluation
#
# Train Random Forest and Gradient Boosting candidates and compare evaluation metrics.

# %%
import sys, pandas as pd
sys.path.append("../src")
from ml_monitoring.config import load_config
from ml_monitoring.models.train import train_candidates
config = load_config("../config/pipeline_config.yaml")
df = pd.read_csv("../data/sample/loan_applications_sample.csv", parse_dates=["application_time"])
report = train_candidates(df, config)
report["champion_model_name"], report["champion_metrics"]
